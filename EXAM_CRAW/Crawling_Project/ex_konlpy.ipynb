# %%
from wordcloud import WordCloud
from konlpy.tag import Okt
from collections import Counter
import matplotlib.pyplot as plt
import platform

# %%
# 한글 글꼴
if(platform.system() == 'Windows'):
    plt.rc('font', family = 'Malgun Gothic')

else:
    plt.rc('font', family = 'AppleGothic')

# %%
text=open('all_lyric.txt',encoding='utf-8').read()

okt=Okt()

# okt함수를 통해 읽어 들인 내용의 형태소를 분석한다.
sentences_tag = []
sentences_tag = okt.pos(text)
noun_adj_list = []

# tag가 명사이거나 형용사인 단어들만 noun_adj_list에 넣어줌
for word, tag in sentences_tag:
    if tag in ['Noun' , 'Adjective']:
        noun_adj_list.append(word)
        
# 가장 많이 나온 단어부터 50개 저장
counts = Counter(noun_adj_list)         # 리스트 항목의 개수를 딕셔너리 형태로 리턴
tags = counts.most_common(50)           # most_common(n): 가장 많은 수를 가지는항목 n개 반환
print(tags)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\User\PycharmProjects\EXAM_CRAW\Crawling_Project\ex_konlpy.ipynb 셀 3 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/User/PycharmProjects/EXAM_CRAW/Crawling_Project/ex_konlpy.ipynb#ch0000001?line=0'>1</a> text=open('all_lyric.txt',encoding='utf-8').read()
#       <a href='vscode-notebook-cell:/c%3A/Users/User/PycharmProjects/EXAM_CRAW/Crawling_Project/ex_konlpy.ipynb#ch0000001?line=2'>3</a> okt=Okt()
#       <a href='vscode-notebook-cell:/c%3A/Users/User/PycharmProjects/EXAM_CRAW/Crawling_Project/ex_konlpy.ipynb#ch0000001?line=4'>5</a> # okt함수를 통해 읽어 들인 내용의 형태소를 분석한다.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'all_lyric.txt'

# %%
# wc 한글 글꼴
if platform.system() == 'Windows':
    path = r'c:\Windows\Fonts\malgun.ttf'
elif platform.system() == 'Darwin': # Mac OS
    path = r'/System/Library/Fonts/AppleGothic'
else:
    path = r'/usr/share/fonts/truetype/name/NanumMyeongjo.ttf'
    
# WordCloud를 생성
wc = WordCloud(font_path=path, background_color="white", max_font_size=80) # 가장 빈도 높은 단어 크기   
cloud = wc.generate_from_frequencies(dict(tags))

# 생성된 WordCloud를 test.jpg로 저장
#cloud.to_file('test.jpg')

plt.figure(figsize=(10, 8))
plt.axis('off')
plt.imshow(cloud)
plt.show()

# %%
for i in range(10):
    text=open(f'lyric{2010+i}.txt',encoding='utf-8').read()

    okt=Okt()

    # okt함수를 통해 읽어 들인 내용의 형태소를 분석한다.
    sentences_tag = []
    sentences_tag = okt.pos(text)
    noun_adj_list = []

    # tag가 명사이거나 형용사인 단어들만 noun_adj_list에 넣어줌
    for word, tag in sentences_tag:
        if tag in ['Noun' , 'Adjective']:
            noun_adj_list.append(word)
            
    # 가장 많이 나온 단어부터 50개 저장
    counts = Counter(noun_adj_list)         # 리스트 항목의 개수를 딕셔너리 형태로 리턴
    tags = counts.most_common(50)           # most_common(n): 가장 많은 수를 가지는항목 n개 반환

    print(tags)
    
    # wc 한글 글꼴
    if platform.system() == 'Windows':
        path = r'c:\Windows\Fonts\malgun.ttf'
    elif platform.system() == 'Darwin': # Mac OS
        path = r'/System/Library/Fonts/AppleGothic'
    else:
        path = r'/usr/share/fonts/truetype/name/NanumMyeongjo.ttf'
        
    # WordCloud를 생성
    wc = WordCloud(font_path=path, background_color="white", max_font_size=80) # 가장 빈도 높은 단어 크기   
    cloud = wc.generate_from_frequencies(dict(tags))

    # 생성된 WordCloud를 test.jpg로 저장
    #cloud.to_file('test.jpg')

    plt.figure(figsize=(10, 8))
    plt.title(f'{2010+i}년 노래가사 빈도수 상위 50개',fontsize=20)
    plt.axis('off')
    plt.imshow(cloud)
    plt.show()
# Out:
# [('너', 197), ('내', 189), ('사랑', 180), ('나', 162), ('말', 108), ('난', 78), ('눈물', 67), ('그', 62), ('날', 59), ('그대', 53), ('가슴', 48), ('이', 46), ('사람', 45), ('니', 45), ('널', 44), ('나나', 44), ('것', 42), ('네', 39), ('모두', 38), ('넌', 38), ('더', 37), ('삐리빠빠', 36), ('우리', 35), ('맘', 34), ('왜', 33), ('생각', 32), ('또', 31), ('걸', 29), ('다시', 29), ('못', 28), ('없어', 28), ('수', 27), ('이제', 26), ('같은', 25), ('때문', 25), ('그냥', 24), ('젠', 24), ('세상', 23), ('고래', 23), ('없는', 22), ('해', 22), ('때', 22), ('하나', 21), ('보고', 20), ('속', 20), ('정말', 20), ('제발', 20), ('어떻게', 19), ('게', 19), ('손', 19)]
# [('너', 270), ('내', 191), ('나', 182), ('사랑', 139), ('난', 123), ('말', 109), ('넌', 77), ('날', 73), ('맘', 68), ('네', 62), ('널', 61), ('그', 56), ('니', 55), ('더', 49), ('그대', 45), ('수', 37), ('없어', 37), ('왜', 36), ('못', 36), ('정말', 36), ('것', 35), ('속', 34), ('이', 33), ('모두', 32), ('때', 31), ('남자', 31), ('또', 29), ('좀', 29), ('걸', 28), ('제발', 28), ('눈', 27), ('가슴', 26), ('다시', 26), ('좋아', 25), ('여자', 25), ('보고', 25), ('알', 25), ('밥', 24), ('그런', 24), ('사이', 24), ('오', 23), ('해', 23), ('눈물', 23), ('오늘', 22), ('안', 22), ('자꾸', 21), ('사람', 21), ('이제', 21), ('곁', 20), ('지금', 20)]
# [('너', 177), ('내', 156), ('사랑', 150), ('나', 118), ('말', 112), ('난', 110), ('니', 102), ('그', 98), ('널', 88), ('이', 82), ('날', 65), ('우리', 48), ('네', 47), ('사람', 45), ('넌', 45), ('또', 45), ('그대', 44), ('밤', 37), ('때', 37), ('더', 36), ('수', 36), ('것', 35), ('마음', 32), ('바로', 30), ('그래', 28), ('눈', 28), ('안', 28), ('왜', 27), ('시간', 26), ('걸', 26), ('속', 26), ('생각', 26), ('하나', 26), ('맘', 26), ('다시', 25), ('눈물', 25), ('보고', 25), ('해', 24), ('못', 24), ('난리', 24), ('뜨거', 24), ('모든', 23), ('소리', 23), ('좀', 22), ('바보', 22), ('이제', 20), ('제발', 20), ('이런', 19), ('순간', 19), ('그런', 18)]
# [('내', 205), ('너', 167), ('나', 148), ('난', 127), ('사랑', 125), ('말', 103), ('네', 86), ('널', 80), ('그대', 77), ('날', 75), ('더', 66), ('넌', 64), ('그', 64), ('없어', 61), ('니', 59), ('눈물', 56), ('오늘', 46), ('예', 45), ('밤', 45), ('왜', 42), ('수', 42), ('이', 41), ('눈', 40), ('걸', 40), ('맘', 39), ('뭐', 39), ('으르렁', 36), ('해', 33), ('속', 32), ('점핑', 30), ('우리', 30), ('혼자', 29), ('또', 29), ('오', 29), ('모습', 28), ('같은', 28), ('마음', 28), ('때', 26), ('가슴', 25), ('없는', 25), ('하루', 25), ('이제', 24), ('다시', 24), ('처음', 23), ('생각', 23), ('봄', 22), ('시간', 22), ('이름', 22), ('못', 21), ('좋아', 21)]
# [('너', 317), ('나', 197), ('내', 189), ('사랑', 143), ('날', 88), ('말', 87), ('난', 85), ('그', 81), ('널', 80), ('왜', 65), ('더', 56), ('것', 55), ('네', 55), ('넌', 55), ('니', 54), ('이', 52), ('우리', 48), ('눈', 46), ('수', 46), ('맘', 45), ('안', 44), ('또', 41), ('지금', 39), ('밤', 36), ('오늘', 35), ('사람', 34), ('그대', 33), ('하나', 31), ('이건', 31), ('좀', 30), ('모든', 30), ('못', 29), ('노래', 29), ('눈물', 27), ('시간', 27), ('건', 27), ('해', 26), ('없어', 26), ('현아', 25), ('생각', 24), ('없는', 24), ('앞', 24), ('걸', 23), ('소리', 23), ('속', 22), ('위', 22), ('손', 22), ('전', 22), ('정말', 22), ('가슴', 21)]
# [('너', 175), ('내', 147), ('난', 115), ('말', 115), ('나', 111), ('날', 87), ('더', 83), ('사랑', 80), ('그', 71), ('것', 66), ('넌', 58), ('네', 56), ('또', 54), ('널', 52), ('없어', 49), ('맘', 48), ('아예', 48), ('해', 47), ('이', 47), ('사람', 47), ('좀', 44), ('미친', 44), ('수', 43), ('우리', 42), ('눈', 39), ('때', 36), ('다운', 36), ('안', 35), ('걸', 35), ('니', 34), ('왜', 34), ('오늘', 33), ('마', 31), ('다시', 31), ('지금', 30), ('속', 30), ('못', 29), ('마음', 29), ('게', 28), ('그냥', 27), ('다른', 27), ('그대', 27), ('남자', 25), ('나나', 25), ('이제', 25), ('자꾸', 25), ('생각', 24), ('저', 22), ('거', 22), ('건', 22)]
# [('내', 229), ('너', 224), ('말', 136), ('나', 121), ('사랑', 110), ('널', 104), ('난', 98), ('그', 94), ('수', 77), ('날', 75), ('넌', 71), ('맘', 69), ('네', 65), ('더', 55), ('걸', 51), ('것', 48), ('왜', 48), ('마음', 46), ('때', 45), ('이', 43), ('안', 40), ('게', 40), ('우리', 37), ('뭐', 36), ('니', 35), ('없는', 34), ('없어', 32), ('시간', 32), ('데', 32), ('자꾸', 31), ('좀', 31), ('지금', 30), ('꿈', 30), ('눈', 29), ('그대', 29), ('못', 28), ('속', 28), ('있어', 28), ('사람', 27), ('해', 27), ('다시', 26), ('눈물', 25), ('모든', 25), ('생각', 25), ('거', 24), ('앞', 24), ('어디', 23), ('곳', 23), ('마', 23), ('밤', 23)]
# [('너', 227), ('내', 185), ('나', 143), ('말', 114), ('난', 102), ('날', 97), ('사랑', 95), ('네', 95), ('것', 94), ('널', 90), ('넌', 86), ('그', 83), ('이', 77), ('맘', 73), ('수', 64), ('왜', 64), ('우리', 47), ('더', 47), ('같아', 44), ('걸', 44), ('다시', 41), ('안', 41), ('그대', 37), ('알', 36), ('해', 36), ('때', 33), ('또', 33), ('생각', 32), ('시간', 32), ('밤', 31), ('오늘', 29), ('매일', 29), ('게', 29), ('마', 29), ('지금', 28), ('정말', 28), ('마음', 28), ('니', 27), ('있어', 27), ('거', 27), ('마지막', 27), ('눈', 26), ('자꾸', 26), ('우린', 25), ('에', 25), ('이제', 24), ('없어', 24), ('찌릿', 24), ('줄', 23), ('못', 23)]
# [('너', 239), ('내', 159), ('나', 124), ('날', 103), ('말', 90), ('난', 89), ('네', 87), ('널', 85), ('넌', 79), ('더', 78), ('사랑', 76), ('해', 69), ('이', 67), ('밤', 60), ('수', 56), ('그', 53), ('것', 51), ('우리', 50), ('걸', 47), ('마음', 44), ('때', 42), ('안', 38), ('맘', 35), ('없는', 33), ('또', 31), ('못', 31), ('왜', 31), ('시간', 30), ('다음', 30), ('눈', 29), ('위', 29), ('삑', 29), ('같아', 27), ('해도', 26), ('듯', 26), ('모든', 25), ('속', 25), ('있는', 24), ('지금', 24), ('없어', 24), ('알', 23), ('니', 23), ('건', 22), ('매일', 22), ('젠', 21), ('생각', 21), ('이제', 21), ('꽃', 21), ('조금', 21), ('어디', 21)]
# [('너', 233), ('나', 166), ('내', 152), ('사랑', 101), ('네', 100), ('말', 87), ('난', 86), ('우리', 74), ('널', 70), ('더', 70), ('수', 70), ('이', 70), ('날', 69), ('그', 67), ('없는', 50), ('그때', 43), ('넌', 42), ('것', 41), ('그대', 41), ('또', 39), ('시간', 37), ('지금', 37), ('걸', 35), ('마음', 35), ('맘', 33), ('젠', 31), ('밤', 31), ('해', 30), ('못', 29), ('거', 29), ('다시', 28), ('없어', 28), ('게', 27), ('왜', 26), ('하루', 26), ('안', 26), ('이제', 25), ('모든', 25), ('노래', 25), ('눈', 23), ('하나', 23), ('니', 23), ('속', 23), ('잔', 23), ('때', 22), ('별', 21), ('그녀', 21), ('달라', 21), ('알', 20), ('생각', 20)]
