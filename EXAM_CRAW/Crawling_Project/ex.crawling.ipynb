# %%
import requests
from bs4 import BeautifulSoup

# %%
headers = {'User-Agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/98.0.4758.102 Safari/537.36'}
url='https://www.genie.co.kr/chart/musicHistory?year=2014&category=0'
html = requests.get(url,headers=headers)
soup = BeautifulSoup(html.text, 'html.parser')
print(len(soup.find('tbody').find_all('tr')))
soup.find_all('tbody')[0].find('tr').attrs['songid'] # 좋은날 코드(80897957)
# Out:
# 49
# '82269281'

# %%
soup.find_all('tbody')[0].find_all('tr')[0].attrs['songid']
# Out:
# '80897957'

# %%
soup.find('tbody').find('tr').attrs['songid'] # 좋은날 코드(80897957)
# Out:
# '80897957'

# %%
soup.find_all('tbody')[0].find_all('tr')[49].attrs['songid'] # 50위
# Out:
# '80877159'

# %%
# https://www.genie.co.kr/detail/songInfo?xgnm=80897957

# %%
# url2='https://www.genie.co.kr/detail/songInfo?xgnm=80897957'
# html2= requests.get(url2,headers=headers)
# soup2= BeautifulSoup(html2.text, 'html.parser')
# soup2.find('pre',{'id':"pLyrics"}).find('p').text.replace('\n',' ').replace('\t','').replace('\r','')

# %%
# print(soup2.find('pre',{'id':"pLyrics"}).find('p').text)

# %%
#soup.find_all('tbody')[6].find('tr').attrs['songid']

# %%
url3='https://www.genie.co.kr/detail/songInfo?xgnm=80877159'
html3= requests.get(url3,headers=headers)
soup3= BeautifulSoup(html3.text, 'html.parser')
soup3.find('pre',{'id':"pLyrics"}).find('p').text.replace('\n',' ').replace('\t','').replace('\r','')
# Out:
# '그대의 입술이 닿으면 간질 간질  마음이 간지러 자꾸만 아잉 아잉  기뻐서 아잉 아잉 예민해 예민해  그대를 1초만 못 봐도 눈물샘에 신호가 떠버려  자꾸만 꺼이 꺼이 보고파 꺼이 꺼이  예민해 예민해 알러지 같은 내 사랑 멀쩡하던 날  시큰하게 훌쩍거리게 줬다 폈다 왔다 갔다  *Oh oh 멋지면 다야 잘생기면 다야  징글 징글 징글 하게   오~ 좋아서 미쳐 미쳐 빠져 빠져 온몸이 저려  뼛속까지 저려 찌릿 찌릿 찌릿 하게  오~ 어떻해 덥썩 덥썩 내 맘 집어 삼키는 너 나 나 나 나……  그대가 툭 던진 농담도 밤새도록 내 맘을 괴롭혀 궁금해  오잉 오잉 생각해 오잉 오잉 예민해 예민해  알러지 같은 내 사랑 얌전하던 날  정신 없게 폴짝거리게 아찔하게 짜릿하게  *Oh oh 멋지면 다야 잘생기면 다야  징글 징글 징글 하게 오~  좋아서 미쳐 미쳐 빠져 빠져 온몸이 저려  뼛속까지 저려 찌릿 찌릿 찌릿 하게  오~ 어떻게 덥썩 덥썩 내 맘  집어 삼키는 너 날 꼼짝 못하게 해버렸죠…… 나만의 사랑 남자 중에 남자 어쩜 어쩜 어쩜이래..  오.. 완벽해 머리부터 발끝까지 내 삶의 보석 내 인생의 기적  오래 오래 오래토록 오~ 영원히  나만 나만 나만 나만 사랑해줘 나 나 나 나…… 아잉♡'

# %%
print(soup3.find('pre',{'id':"pLyrics"}).find('p').text)
# Out:
# 그대의 입술이 닿으면 간질 간질
# 마음이 간지러 자꾸만 아잉 아잉
# 기뻐서 아잉 아잉 예민해 예민해
# 그대를 1초만 못 봐도 눈물샘에 신호가 떠버려
# 자꾸만 꺼이 꺼이 보고파 꺼이 꺼이
# 예민해 예민해 알러지 같은 내 사랑 멀쩡하던 날
# 시큰하게 훌쩍거리게 줬다 폈다 왔다 갔다
# *Oh oh 멋지면 다야 잘생기면 다야
# 징글 징글 징글 하게
#
# 오~ 좋아서 미쳐 미쳐 빠져 빠져 온몸이 저려
# 뼛속까지 저려 찌릿 찌릿 찌릿 하게
# 오~ 어떻해 덥썩 덥썩 내 맘 집어 삼키는 너 나 나 나 나……
# 그대가 툭 던진 농담도 밤새도록 내 맘을 괴롭혀 궁금해
# 오잉 오잉 생각해 오잉 오잉 예민해 예민해
# 알러지 같은 내 사랑 얌전하던 날
# 정신 없게 폴짝거리게 아찔하게 짜릿하게
# *Oh oh 멋지면 다야 잘생기면 다야
# 징글 징글 징글 하게 오~
# 좋아서 미쳐 미쳐 빠져 빠져 온몸이 저려
# 뼛속까지 저려 찌릿 찌릿 찌릿 하게
# 오~ 어떻게 덥썩 덥썩 내 맘
# 집어 삼키는 너 날 꼼짝 못하게 해버렸죠……
# 나만의 사랑 남자 중에 남자 어쩜 어쩜 어쩜이래..
# 오.. 완벽해 머리부터 발끝까지 내 삶의 보석 내 인생의 기적
# 오래 오래 오래토록 오~ 영원히
# 나만 나만 나만 나만 사랑해줘 나 나 나 나…… 아잉♡

# %%
soup3
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <!--[if lte IE 6]><html dir="ltr" class="no-js ie6"><![endif]-->
# <!--[if lte IE 7]><html dir="ltr" class="no-js ie7"><![endif]-->
# <!--[if IE 8]><html dir="ltr" class="no-js ie8"><![endif]-->
# <!--[if IE 9]><html dir="ltr" class="no-js ie9"><![endif]-->
# <!--[if (gte IE 10)|!(IE)]><!--><html class="no-js" dir="ltr"><!--<![endif]-->
# <title>음악, 그리고 설레임 - 지니</title>
# <meta charset="utf-8"/>
# <meta content="d17289f97c7f294985a9b0eb3649a45ac5ceeee2" name="naver-site-verification"/>
# <meta content="-l7MNwwsDcn29Pnu00OagSrpDUPbjqLYoY08rhXLde8" name="google-site-verification"/>
# <meta content="가격은 가볍게, 추천은 확실하게! 최저가로 즐기는 프리미어 사운드! 국내 최초 실시간 TOP 200 차트" name="description"/>
# <meta content="width=1200" name="viewport"/>
# <meta content="" property="og:url"/>
# <meta content="website" property="og:type"/>
# ...

# %%
# artist
soup3.find_all('span', {'class':"value"})[0].text
# Out:
# '오렌지캬라멜 (ORANGE CARAMEL)'

# %%
# 장르
soup3.find_all('span', {'class':"value"})[2].text
# Out:
# '가요 / 댄스'

# %%
# title
url4='https://www.genie.co.kr/detail/songInfo?xgnm=80897957'
html4= requests.get(url4,headers=headers)
soup4= BeautifulSoup(html4.text, 'html.parser')
soup4.find('pre',{'id':"pLyrics"}).find('div').text.split('-')[0].strip()
# Out:
# '좋은 날'

# %%
# 나이런사람이야
url4='https://www.genie.co.kr/detail/songInfo?xgnm=80783196'
html4= requests.get(url4,headers=headers)
soup4= BeautifulSoup(html4.text, 'html.parser')
soup4
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <!--[if lte IE 6]><html dir="ltr" class="no-js ie6"><![endif]-->
# <!--[if lte IE 7]><html dir="ltr" class="no-js ie7"><![endif]-->
# <!--[if IE 8]><html dir="ltr" class="no-js ie8"><![endif]-->
# <!--[if IE 9]><html dir="ltr" class="no-js ie9"><![endif]-->
# <!--[if (gte IE 10)|!(IE)]><!--><html class="no-js" dir="ltr"><!--<![endif]-->
# <title>음악, 그리고 설레임 - 지니</title>
# <meta charset="utf-8"/>
# <meta content="d17289f97c7f294985a9b0eb3649a45ac5ceeee2" name="naver-site-verification"/>
# <meta content="-l7MNwwsDcn29Pnu00OagSrpDUPbjqLYoY08rhXLde8" name="google-site-verification"/>
# <meta content="가격은 가볍게, 추천은 확실하게! 최저가로 즐기는 프리미어 사운드! 국내 최초 실시간 TOP 200 차트" name="description"/>
# <meta content="width=1200" name="viewport"/>
# <meta content="" property="og:url"/>
# <meta content="website" property="og:type"/>
# ...

# %%
#장르, 가수
soup4.find_all('span', {'class':"value"})[2].text
soup4.find_all('span', {'class':"value"})[0].text
# Out:
# 'DJ DOC'

# %%
# 제목
' '.join(soup4.find('h2',{'class':'name'}).text.split()[1:])
# Out:
# '나 이런사람이야'
