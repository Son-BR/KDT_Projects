# %%
import pymysql
import pandas as pd
import matplotlib.pyplot as plt
import platform

# %%
# 의사 진단 만성질환수

conn = pymysql.connect(host='localhost', user='root',password='950603', db = 'project_db', charset='utf8')
cur=conn.cursor()
cur.execute("""select 시점,만성질환수별,소계 from disease_doctor
WHERE 만성질환수별 in ('없음 (%)','1개 (%)','2개 (%)','3개 이상 (%)') 
order by 시점;""")

rows=cur.fetchall()

year=[2014,2017,2020]

disease0=[]
disease1=[]
disease2=[]
disease3=[]
for i in range(len(rows)):
    if (i+1)%4==1: disease0.append(rows[i][2])
    elif (i+1)%4==2: disease1.append(rows[i][2])
    elif (i+1)%4==3: disease2.append(rows[i][2])
    else: disease3.append(rows[i][2])

plt.figure(dpi=100,figsize=(20,5))

plt.title("Disease Count")



plt.plot(year,disease0)
plt.plot(year,disease1)
plt.plot(year,disease2)
plt.plot(year,disease3)


plt.legend(['disease0','disease1','disease2','disease3'])
plt.show()

cur.close()
conn.close()

# %%
# 의사 진단 만성질환수

conn = pymysql.connect(host='localhost', user='root',password='950603', db = 'project_db', charset='utf8')
cur=conn.cursor()
cur.execute("""select 시점,만성질환수별,소계 from disease_doctor
WHERE 만성질환수별 in ('없음 (%)','1개 (%)','2개 (%)','3개 이상 (%)') 
order by 시점;""")

df=pd.DataFrame(cur.fetchall())

fig, axes = plt.subplots(1, 3, figsize=(20, 10))
fig.suptitle('연도별 만성질환 수', fontsize=15)

for i in range(3):
    plt.subplot(1,3,i+1)
    plt.pie(df[2][i*4:(i+1)*4],labels=['없음', '1개', '2개', '3개 이상'])

#plt.pie(df[2][:4],labels=['없음', '1개', '2개', '3개 이상'])
# cur.close()
# conn.close()

# %%
# def get_cursor():
#     conn = pymysql.connect(host='localhost', user='root',password='950603', db = 'project_db', charset='utf8')
    
#     return conn.cursor()

# %%
conn = pymysql.connect(host='localhost', user='root',password='950603', db = 'project_db', charset='utf8')

cur=conn.cursor()
cur.execute("""select * from disease_sort
where 항목 in ('유병률 (%)','치료율 (%)') and 성별='전체';""")

rows=cur.fetchall()

df=pd.DataFrame(rows)
df=df.T
disease=['항목', '성별', '시점', '고혈압', '뇌졸중(중풍 뇌경색)', '고지혈증(이상지질혈증)', '협심증 심근경색증',
       '기타 심장질환', '당뇨병', '갑상선 질환', '골관절염 류머티즘관절염', '골다공증', '요통 좌골신경통',
       '만성기관지염 폐기종(CO포인트D)', '천식', '폐결핵 결핵', '백내장', '녹내장', '만성중이염', '악성신생물(암)',
       '위,십이지장궤양', '간염', '간경변', '만성신장질환', '전립선비대증', '요실금', '성병(매독 등)', '빈혈',
       '피부병', '우울증', '치매', '골절 탈골 및 사고후유증', '불면증', '파킨슨', '노인성 난청', '기타']

df.insert(0,'disease',disease)


df=df.iloc[3:]
df.columns=['disease','유병률2014','유병률2017','유병률2020','치료율2014','치료율2017','치료율2020']

cur.close()
conn.close()

df.replace('-',None,inplace=True)
df.replace('0',None,inplace=True)
df.dropna(inplace=True)

df.to_csv('./data/disease_sort2.csv',encoding='utf-8',index=False)

# %%
df=pd.read_csv(r'./data/disease_sort.csv',encoding='utf-8')

# %%
df.columns
# Out:
# Index(['항목', '성별', '시점', '고혈압', '뇌졸중(중풍 뇌경색)', '고지혈증(이상지질혈증)', '협심증 심근경색증',
#        '기타 심장질환', '당뇨병', '갑상선 질환', '골관절염 류머티즘관절염', '골다공증', '요통 좌골신경통',
#        '만성기관지염 폐기종(CO포인트D)', '천식', '폐결핵 결핵', '백내장', '녹내장', '만성중이염', '악성신생물(암)',
#        '위?십이지장궤양', '간염', '간경변', '만성신장질환', '전립선비대증', '요실금', '성병(매독 등)', '빈혈',
#        '피부병', '우울증', '치매', '골절 탈골 및 사고후유증', '불면증', '파킨슨', '노인성 난청', '기타'],
#       dtype='object')

# %%
['항목', '성별', '시점', '고혈압', '뇌졸중(중풍 뇌경색)', '고지혈증(이상지질혈증)', '협심증 심근경색증',
       '기타 심장질환', '당뇨병', '갑상선 질환', '골관절염 류머티즘관절염', '골다공증', '요통 좌골신경통',
       '만성기관지염 폐기종(CO포인트D)', '천식', '폐결핵 결핵', '백내장', '녹내장', '만성중이염', '악성신생물(암)',
       '위?십이지장궤양', '간염', '간경변', '만성신장질환', '전립선비대증', '요실금', '성병(매독 등)', '빈혈',
       '피부병', '우울증', '치매', '골절 탈골 및 사고후유증', '불면증', '파킨슨', '노인성 난청', '기타']
# Out:
# ['항목',
#  '성별',
#  '시점',
#  '고혈압',
#  '뇌졸중(중풍 뇌경색)',
#  '고지혈증(이상지질혈증)',
#  '협심증 심근경색증',
#  '기타 심장질환',
#  '당뇨병',
#  '갑상선 질환',
#  '골관절염 류머티즘관절염',
#  '골다공증',
#  '요통 좌골신경통',
#  '만성기관지염 폐기종(CO포인트D)',
#  '천식',
#  '폐결핵 결핵',
#  '백내장',
#  '녹내장',
#  '만성중이염',
#  '악성신생물(암)',
#  '위?십이지장궤양',
#  '간염',
#  '간경변',
#  '만성신장질환',
#  '전립선비대증',
#  '요실금',
#  '성병(매독 등)',
#  '빈혈',
#  '피부병',
#  '우울증',
#  '치매',
#  '골절 탈골 및 사고후유증',
#  '불면증',
#  '파킨슨',
#  '노인성 난청',
#  '기타']

# %%
# df -> 데이터베이스 저장
# from sqlalchemy import create_engine
# engine = 'mysql+pymysql://root:950603@localhost/project_db'
# db_connection = create_engine(engine)
# conn = db_connection.connect()

# df.to_sql(name='disease_sort2', con=db_connection, if_exists='replace',index=False)

# %%
# 유병율 상위 10개 만성질병
conn = pymysql.connect(host='localhost', user='root',password='950603', db = 'project_db', charset='utf8')

cur=conn.cursor()
cur.execute("""select disease, 유병률2020, 치료율2020 from disease_sort2
order by 유병률2020 desc
limit 10;""")

rows=cur.fetchall()

df=pd.DataFrame(rows)

# 한글 글꼴
if(platform.system() == 'Windows'):
    plt.rc('font', family = 'Malgun Gothic')

else:
    plt.rc('font', family = 'AppleGothic')

plt.figure(dpi=100,figsize=(20,5))
plt.xticks(rotation=20,fontsize=20)
plt.title("유병율 상위 10개 만성질병과 치료율",fontsize=20)

plt.bar(df[0],df[1])
plt.plot(df[0],df[2])
plt.legend(['치료율','유병률'],fontsize=10)
plt.show()

# %%
# 치료율 하위 10개 만성질병

conn = pymysql.connect(host='localhost', user='root',password='950603', db = 'project_db', charset='utf8')

cur=conn.cursor()
cur.execute("""select disease, 치료율2020 from disease_sort2
order by 치료율2020
limit 10;""")

rows=cur.fetchall()

df=pd.DataFrame(rows)

# 한글 글꼴
if(platform.system() == 'Windows'):
    plt.rc('font', family = 'Malgun Gothic')

else:
    plt.rc('font', family = 'AppleGothic')

plt.figure(dpi=100,figsize=(20,5))
plt.xticks(rotation=20,fontsize=20)
plt.title("치료율 하위 10개 만성질병",fontsize=20)

plt.bar(df[0],df[1])

plt.show()

# %%
# 우울증상

conn = pymysql.connect(host='localhost', user='root',password='950603', db = 'project_db', charset='utf8')
cur=conn.cursor()
cur.execute("""select 시점,소계 from blues
where 증상별 = '우울증상 (%)';""")

rows=cur.fetchall()

df=pd.DataFrame(rows)

plt.figure(dpi=100,figsize=(20,5))

plt.title("우울증상",fontsize=20)

plt.plot(df[0],df[1])

plt.show()

# cur.close()
# conn.close()

# %%
# 시설

conn = pymysql.connect(host='localhost', user='root',password='950603', db = 'project_db', charset='utf8')
cur1=conn.cursor()
cur1.execute("""select 시점, (노인요양시설+노인요양공동생활가정) as 시설수
from facility
WHERE 항목='시설수 (개소)';""")

cur2=conn.cursor()
cur2.execute("""select 시점, (노인요양시설+노인요양공동생활가정) as 입소정원
from facility
WHERE 항목='입소정원 (명)';""")


df1=pd.DataFrame(cur1.fetchall())
df2=pd.DataFrame(cur2.fetchall())

plt.rcParams['figure.figsize'] = (20, 7)

fig, ax1 = plt.subplots()
ax1.plot(df1[0],df1[1],color='blue')
ax1.legend(['시설수'],loc='upper left')
plt.title('의료복지시설의 수와 입소정원',fontsize=20)

ax2 = ax1.twinx()

ax2.plot(df1[0],df2[1],color='red')
ax2.legend(['입소정원'],loc='upper right')

plt.show()

# %%
# 수진율 및 미치료율

conn = pymysql.connect(host='localhost', user='root',password='950603', db = 'project_db', charset='utf8')
cur=conn.cursor()
cur.execute("""select 수진율및미치료율별,과목별,소계 from treat_rate
where 과목별 in ('건강검진','치매검진','병의원 진료','치과 진료') and 시점='2020';""")

rows=cur.fetchall()

df=pd.DataFrame(rows)

df
# Out:
#           0       1   2
# 0   수진율 (%)    건강검진  77
# 1   수진율 (%)    치매검진  42
# 2  미치료율 (%)  병의원 진료   2
# 3  미치료율 (%)   치과 진료   3

# %%
# 분위별 검강검진
conn = pymysql.connect(host='localhost', user='root',password='950603', db = 'project_db', charset='utf8')
cur=conn.cursor()
cur.execute("""select 수진율및미치료율별,과목별,제1오분위,제2오분위,제3오분위,제4오분위,제5오분위
from treat_rate
where 과목별 = '건강검진' and 시점='2020';""")

df=pd.DataFrame(cur.fetchall())

x_label=['제1오분위','제2오분위','제3오분위','제4오분위','제5오분위']


plt.figure(dpi=100,figsize=(20,5))

plt.title("분위별 건강검진 비율",fontsize=20)

plt.plot(x_label,df.iloc[0][2:])

plt.show()

# %%
# 분위별 검강검진
conn = pymysql.connect(host='localhost', user='root',password='950603', db = 'project_db', charset='utf8')
cur=conn.cursor()
cur.execute("""select 수진율및미치료율별,과목별,제1오분위,제2오분위,제3오분위,제4오분위,제5오분위
from treat_rate
where 과목별 = '건강검진' and 시점='2020';""")

df=pd.DataFrame(cur.fetchall())

x_label=['제1오분위','제2오분위','제3오분위','제4오분위','제5오분위']


plt.figure(dpi=100,figsize=(20,5))

plt.title("분위별 건강검진 비율",fontsize=20)

plt.plot(x_label,df.iloc[0][2:])

plt.show()
