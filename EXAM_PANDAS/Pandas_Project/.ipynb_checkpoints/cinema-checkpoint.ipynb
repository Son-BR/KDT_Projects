# %%
# 모듈 로딩
import pandas as pd
import matplotlib.pyplot as plt

# 파일
pop_d=pd.read_excel('./daegu_population_2020.xlsx',header=list(range(0,6)))
cin_d=pd.read_excel('./daegu_cinema.xlsx')
pop_s=pd.read_csv('./seoul_population_2020.csv')
cin_s=pd.read_csv('./seoul_cinema.csv')

# %%
pop_d
# Out:
#    1. 구.군별 세대 및 인구현황                                                           \
#   Unnamed: 0_level_1 Unnamed: 1_level_1 Unnamed: 2_level_1 Unnamed: 3_level_1
#                대구광역시              대구광역시              대구광역시              대구광역시
#                  구·군         합        계         합        계         합        계
#   Unnamed: 0_level_4        인         구        인         구        인         구
#   Unnamed: 0_level_5                  계                  남                  여
# 0                 총계            2446144            1208020            1238124
# 1                 중구              77262              37132              40130
# 2                 동구             343685             169034             174651
# 3                 서구             172879              86770              86109
# 4                 남구             148247              71170              77077
# 5                 북구             444923             221416             223507
# 6                수성구             425987             205983             220004
# 7                달서구             568481             281390             287091
# 8                달성군             264680             135125             129555
#
#                                                                                \
#   Unnamed: 4_level_1 Unnamed: 5_level_1 Unnamed: 6_level_1 Unnamed: 7_level_1
#                대구광역시              대구광역시              대구광역시              대구광역시
#            한   국   인          한   국   인          한   국   인          한   국   인
#                   세대        인         구        인         구        인         구
#   Unnamed: 4_level_5                  계                  남                  여
# 0            1056627            2418346            1193109            1225237
# 1              39111              76547              36799              39748
# 2             155865             341920             168443             173477
# 3              83437             170700              85572              85128
# 4              76582             146632              70471              76161
# 5             187494             440263             219197             221066
# 6             170870             424314             205293             219021
# 7             235303             558631             275626             283005
# 8             107965             259339             131708             127631
#
#
#   Unnamed: 8_level_1 Unnamed: 9_level_1 Unnamed: 10_level_1
#     2020. 12. 31. 현재   2020. 12. 31. 현재    2020. 12. 31. 현재
#        외     국     인      외     국     인       외     국     인
#       인            구     인            구      인            구
#                    계                  남                   여
# 0              27798              14911               12887
# 1                715                333                 382
# 2               1765                591                1174
# 3               2179               1198                 981
# 4               1615                699                 916
# 5               4660               2219                2441
# 6               1673                690                 983
# 7               9850               5764                4086
# 8               5341               3417                1924
